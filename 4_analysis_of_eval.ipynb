# %%
eval_dir = '/Users/jnaiman/Downloads/tmp/ocrpost/eval/'
eval_file = 'evalsavecorrs.pickle'

# %%
import pickle

# %%
with open(eval_dir + eval_file, 'rb') as f:
    corrections = pickle.load(f)

# %%
corrections
# Out:
# [' The sueeeted td tottoa  ail  laa   o  th  nerr ntssars aacretion disk  r m X o   -ra, hhe ting of the reei   ne ken ee  th   T  ba   str ehtht  uh   f the hi e  aaking the spectral asalas paara a  ar  MMy s 2  ',
#  ' She SS   source would be ome aaot r  ha ns  in      he  in  oo  o     har  which in ihn ie  i  this sequations sta  from n   egh in',
#  'aaifes  en sisee n  re cecccccoodang  o     )  ) ',
#  ' BB BB frrve re r B BS  g 233er 3333  ar  or n fro  the frm  a   bnd debaa  edee g  h nness of  DCDD DSCCCCC  nd SCC     a aiin Fi ure   a    for all  66eeeeec  th  s es  f  Fe  n  ig Fe grr',
#  '  he  Fme  S  is used oo  th  of soscrcecspectra eetraation     th  sueccs speccrr',
# ...
